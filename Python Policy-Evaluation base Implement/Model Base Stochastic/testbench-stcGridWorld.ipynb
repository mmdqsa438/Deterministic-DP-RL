# %%
from Stochastic_Grid_world import GridWorld, standard_sticky_GW
from pprint import pprint

# %%
g = standard_sticky_GW()
pprint(g.probabilities)

# %%
pprint(g.states)

print("\n\n-----------------------------\n> Walking in world:")
print("> current state:",g.current_state)
print("> move UP by reward:   ",g.transition("U"), "current state:",g.current_state)
print("> move RIGHT by reward:",g.transition("U"), "current state:",g.current_state)
print("> move RIGHT by reward:",g.transition("R"), "current state:",g.current_state)
print("> move RIGHT by reward: ",g.transition("R"), "current state:",g.current_state)
print("\n> Game over check:",g.game_over())


print("\n\n> move UP probability <(1,0),(2,0),'U'>",g.probability((1,0),(2,0),'U'))
print("> move UP probability <(1,1),(2,1),'U'>",g.probability((1,0),(2,1),'U'))
print("> move UP probability <(1,1),(2,3),'U'>",g.probability((1,3),(2,3),'U'))
# Out:
# [(0, 0),
#  (0, 1),
#  (0, 2),
#  (0, 3),
#  (1, 0),
#  (1, 1),
#  (1, 2),
#  (1, 3),
#  (2, 0),
#  (2, 1),
#  (2, 2),
#  (2, 3)]
#
#
# -----------------------------
# > Walking in world:
# > current state: (0, 1)
# > move UP by reward:    0.0 current state: (0, 1)
# > move RIGHT by reward: 0.0 current state: (0, 1)
# > move RIGHT by reward: -0.09 current state: (0, 2)
# > move RIGHT by reward:  -0.09 current state: (0, 2)
#
# > Game over check: False
#
#
# > move UP probability <(1,0),(2,0),'U'> 0.7
# > move UP probability <(1,1),(2,1),'U'> 0.0
# > move UP probability <(1,1),(2,3),'U'> 0.7
